# %%
import sys
sys.path.append("scripts")
from scripts.visualise import Visualiser

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Visualiser = Visualiser()

# %%
df = Visualiser.load_data("/kaggle/input/bank-data/Analysed_review.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   source_id          1200 non-null   object
#  1   review             1200 non-null   object
#  2   rating             1200 non-null   int64
#  3   date               1200 non-null   object
#  4   bank               1200 non-null   object
#  5   sentiment_score    1200 non-null   float64
#  6   sentiment_label    1200 non-null   object
#  7   cleaned_text       1196 non-null   object
#  8   identified_theme   1200 non-null   object
#  9   theme_score        1200 non-null   float64
#  10  discovered_topic   1200 non-null   int64
#  11  topic_probability  1200 non-null   float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 112.6+ KB

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["bank"].value_counts()
# Out:
# bank
# CBE       400
# BOA       400
# Dashen    400
# Name: count, dtype: int64

# %%
Visualiser.plot_theme_distribution(df , "CBE")

# %%
Visualiser.plot_theme_distribution(df , "BOA")

# %%
Visualiser.plot_theme_distribution(df , "Dashen")

# %%
Visualiser.plot_bank_rating_distribution(df , "CBE")

# %%
Visualiser.plot_bank_rating_distribution(df , "BOA")

# %%
Visualiser.plot_bank_rating_distribution(df , "Dashen")

# %%
Visualiser.plot_sentiment_trend_by_bank( df ,"CBE")

# %%
Visualiser.plot_sentiment_trend_by_bank( df ,"BOA")

# %%
Visualiser.plot_sentiment_trend_by_bank( df ,"Dashen")
